# %% [markdown]
# # Assignment III - NLP: Seinfeld or Friends?

# %% [markdown]
# This assignment is going to cover the topics of neural networks for NLP. This is the final task before the project.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Description

# %% [markdown]
# You are given a dataset containing the scripts of all Seinfeld and Friends episodes. Your goal is to create a deep learning model that could identify whether a line was taken from a Seinfeld episode or a Friends episode.

# %% [markdown]
# You are required to train your model on "train.csv", and finally report your accuracy score on "test.csv". Of course, you are encouraged to further split "train.csv" into train and validation datasets.

# %% [markdown]
# There are 5 columns in the dataset: Dialogue, Character, Episode, Show, and Dialogue_length. You are allowed to use all of them for EDA/pre-processing but you're only allowed to use 'Dialogue' and 'Show' during training!
#
# Your (pseudo) code should look something like:
#
# ```
# x_train = train['Dialogue']
# y_train = train['Show']
# ```
#
#
# The same goes for test.

# %% [markdown]
# You can load the data using:

# %%
import pandas as pd
train_df = pd.read_csv('https://raw.githubusercontent.com/odedovadia/AdvancedMLDLCourse/main/Assignments/Assignment%20II%20-%20NLP/train.csv')
test_df = pd.read_csv('https://raw.githubusercontent.com/odedovadia/AdvancedMLDLCourse/main/Assignments/Assignment%20II%20-%20NLP/test.csv')

# %% [markdown]
# You are required to:
#
# 1.   Build and train a model, and then test it on the test set.
# 2.   Explore your results. Reload the test set, and filter it by different characters. e.g. report the accuracy score only for Jerry lines, Rachel lines, etc. You should repeat this process for each character (10 overall). Plot and visualize your results, and see if your model is better at correctly classifying Seinfeld vs. Friends lines for specific characters.

# %% [markdown]
# Guidelines: properly pre-process and clean the data as we saw in class. This is one of the most important aspects in order to succeed in NLP!
#
# An accuracy of about 80% on the **test** set is a very good result.

# %% [markdown]
# ## Submission guidelines

# %% [markdown]
# Practically the same guidelines as before.
#
# **This is a group project (3-4 members)**. Submissions must include the names of all students in the first paragraph.
#
# Once you are done with the coding part on Google Colab, click "clear all outputs", followed by "reset and run all". This verifies that your code runs smoothly. You do not need to retrain the model each time, you can save the weights and just load the trained model.
# **Please** make sure that the results and outputs are visible, and that the code is well documented with comments describing your actions.
#
# The submission is done using Github. One of the team members has to open a Github account, and open a repository for the assignment.
# Proceed to upload the notebook to the Github repo. In Moodle, all you need to do is submit a link to the Github repo.
#
#
# You are required to submit two different files:
# 1.   Your Google Colab notebook with the code.
# 2.   A CSV file called '**exercise3.csv**' containing 1 row for your best model with the following fields:
#       *   Your **test** set accuracy
#       *   Your **train** set accuracy
#       *   Number of trainable parameters
#       *   Number of layers
#       *   Regularization methods (e.g. dropout, batch normalization etc., just list them all).
#       *   Number of epochs
#       *   Choice of loss function
#       *   Choice of optimizer
#       *   Embedding dimension (if used)
